# %% [markdown]
# # Ejercicio 1

# %%
nums = [1, 2, 3, 4, 5]

def cuadrado(x): 
    return x**2

list(map(cuadrado, nums))
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# # Ejercicio 2

# %%
nums = [10, 15, 20, 25, 30]

# %% [markdown]
# # Ejercicio 3

# %%
from functools import reduce
nums = [1, 2, 3, 4, 5]

# %% [markdown]
# # Ejercicio 4

# %%
nombres = ["ana" , "luis" , "pedro" , "alberto"]

# %% [markdown]
# # Ejercicio 5

# %%
precios = [100, 200, 300]

# %% [markdown]
# # Ejercicio 6

# %%
alumnos = [
    {"nombre": "Ana" , "nota": 7},
    {"nombre": "Luis" , "nota": 4},
    {"nombre": "Marta" , "nota": 9},
    {"nombre": "Pedro" , "nota": 5}
]
