# %% [markdown]
# # ¡¡ANTES DE COMENZAR CAMBIA EL NOMBRE DE ESTE ARCHIVO !!
#
# Cambia el nombre del archivo de modo que empiece con las tres siguientes letras `P1-` y vaya seguido del nombre del alumno separados de con un guión `-`. Para los espacios en blanco usar guiones bajos `_`
#
# Ejemplo para un alumno:
#
# `P1-Don_Quijote.pynb`
#
# ## Recuerda que la entrega debe hacerse en formato `.ipynb`

# %% [markdown]
# ## A. EXPLORACIÓN DATAFRAME

# %% [markdown]
# ### A1. Importación de librerías necesarias

# %%
# TODO
# pandas, libreria para abrir un csv. como cargo un arcvhibo cuando quiero leer un csv
import pandas as pd
print(pd.__version__)

df = pd.read_csv('/Users/stephantrf/Desktop/Desarrollo/workspaces/Python-workspace/notebooks/Clase/T2>S8>PracticaClase/apachelog.csv',  encoding='utf-8', sep="|")
df
# Out:
# 2.3.2
#        DireccionIP;IdUsr;NombreUsr;FechaHora;MetodoHTTP;Ruta;VersionHTTP;EstadoHTTP;Bytes;Column10;Column11
# 0       in24.inetnebr.com;-;-;01/08/1995 0:00;GET;/shu...
# 1       uplherc.upl.com;-;-;01/08/1995 0:00;GET;/;HTTP...
# 2       uplherc.upl.com;-;-;01/08/1995 0:00;GET;/image...
# 3       uplherc.upl.com;-;-;01/08/1995 0:00;GET;/image...
# 4       uplherc.upl.com;-;-;01/08/1995 0:00;GET;/image...
# ...                                                   ...
# 977764  www.neocom.ca;-;-;21/08/1995 19:41;GET;/images...
# 977765  www.neocom.ca;-;-;21/08/1995 19:42;GET;/histor...
# 977766  mty0201.infosel.com.mx;-;-;21/08/1995 19:42;GE...
# 977767  www.neocom.ca;-;-;21/08/1995 19:42;GET;/histor...
# 977768  ip75.van3.pacifier.com;-;-;21/08/1995 19:42;GE...
#
# [977769 rows x 1 columns]

# %% [markdown]
# ### A2. Carga del archivo
# - usa utf-8
# - usa el separador adecuado

# %%
#TODO
df = pd.read_csv('/Users/stephantrf/Desktop/Desarrollo/workspaces/Python-workspace/notebooks/Clase/T2>S8>PracticaClase/apachelog.csv',  encoding='utf-8', sep="|")

# %% [markdown]
# ### A3. Explora el dataframe

# %%
#TODO
print(df)
print(df.describe())
print(df.info)
# Out:
#        DireccionIP;IdUsr;NombreUsr;FechaHora;MetodoHTTP;Ruta;VersionHTTP;EstadoHTTP;Bytes;Column10;Column11
# 0       in24.inetnebr.com;-;-;01/08/1995 0:00;GET;/shu...
# 1       uplherc.upl.com;-;-;01/08/1995 0:00;GET;/;HTTP...
# 2       uplherc.upl.com;-;-;01/08/1995 0:00;GET;/image...
# 3       uplherc.upl.com;-;-;01/08/1995 0:00;GET;/image...
# 4       uplherc.upl.com;-;-;01/08/1995 0:00;GET;/image...
# ...                                                   ...
# 977764  www.neocom.ca;-;-;21/08/1995 19:41;GET;/images...
# 977765  www.neocom.ca;-;-;21/08/1995 19:42;GET;/histor...
# 977766  mty0201.infosel.com.mx;-;-;21/08/1995 19:42;GE...
# 977767  www.neocom.ca;-;-;21/08/1995 19:42;GET;/histor...
# 977768  ip75.van3.pacifier.com;-;-;21/08/1995 19:42;GE...
#
# [977769 rows x 1 columns]
#        DireccionIP;IdUsr;NombreUsr;FechaHora;MetodoHTTP;Ruta;VersionHTTP;EstadoHTTP;Bytes;Column10;Column11
# count                                              977769
# ...

# %% [markdown]
# ### A4. Muestra los valores unicos de tus columnas MetodoHTTP y EstadoHTTP
# AYUDA: usa método unique

# %%
#TODO
print(df["MetodoHTTP"].nunique(), df["EstadoHTTP"].nunique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/Desarrollo/workspaces/Python-workspace/.venv-preso/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MetodoHTTP'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ### A5. Cuenta el numero de valores diferentes de las columnas
# AYUDA: usa método nunique

# %%
#TODO
print(df.nunique())
# Out:
# DireccionIP;IdUsr;NombreUsr;FechaHora;MetodoHTTP;Ruta;VersionHTTP;EstadoHTTP;Bytes;Column10;Column11    965370
# dtype: int64

# %% [markdown]
# ### A6. Explora cuantos valores nan hay por columna
# AYUDA: usa metodo isna()sum() o revisa tu exploracion del df

# %%
#TODO
print(df.isna())
print(df.sum())

# %% [markdown]
# ### A6. RESUMEN EXPLORACION

# %% [markdown]
# TODO: Explica con tus palabras lo obtenido en la exploracion
#
# En la exloración obtenemos una vista previa del datafame.

# %% [markdown]
# ## B. LIMPIEZA DATAFRAME
# - B0. Eliminamos las columnas que no contienen los datos previstos en el listado de campos
# - B1. Trabajaremos SOLO con las columnas 1,4,5,6,8 y 9
# - B2. Transformamos las columnas a los tipos de datos que nos interesan

# %%
# B0. Elimina columnas, almacena el dataframe en df_limpio y comprueba que ya no existen

# %%
#B1. Haz un nuevo dataset (df_nuevo) con las columnas de trabajo 
#AYUDA: usa .iloc o .loc y crea una copia superficial

# %%
#B2. Transforma los datos de las columnas 1,4,5,6,8, y 9 en los correctos y comprueba los tipos
# - numeros: float o int
# . fechas con datetime
# - cadenas en string

# %%
# TODO:COLUMNAS TIPO STRING

# %%
# TODO: COLUMNAS FECHA

# %%
# TODO:COLUMNAS NUMÉRICAS

# %% [markdown]
# PREGUNTA 1: ¿Aun tienes valores nulos? ¿Donde?

# %%
# TODO: Elimina los registros con valores nan en las columnas numericas, si existen
#AYUDA: usa df.dropna con subset

# %% [markdown]
# PREGUNTA 2: ¿cuantos valores tiene ahora tu dataset?

# %% [markdown]
# ### C. ESTADISTICAS
# Calcula valores estadisticos de tus columnas numericas
